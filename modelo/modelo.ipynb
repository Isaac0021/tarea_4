# %%
import pandas as pd

# %%
df = pd.read_csv("documents/Tarea_4/data/cardio_train.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("documents/Tarea_4/data/cardio_train.csv")
#
# NameError: name 'pd' is not defined
